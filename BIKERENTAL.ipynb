# %%
from bikeRental import BikeRental,Customer

def main():
    shop = BikeRental(100)
    customer = Customer()

    while True:
        print("""
        ====== Bike Rental Shop =======
        1. Display available bikes
        2. Request a bike on hourly basis $5
        3. Request a bike on daily basis $20
        4. Request a bike on weekly basis $60
        5. Return a bike
        6. Exit
        """)
        
        choice = input("enter ur choice:")
        
        try:
            choice = int(choice)
        except ValueError:
            print("that's not an int")
            continue
            
        if choice == 1:
            shop.displaystock()
        
        elif choice ==2:
            customer.rentalTime = shop.rentbikeonhourlybasis(customer.requestbike())
            customer.rentalBasis = 1
            
            
        elif choice == 3:
            customer.rentalTime = shop.rentbikeondailybasis(customer.requestbike())
            customer.rentalBasis = 2
            
        elif choice == 4:
            customer.rentalTime = shop.rentbikeonweeklybasis(customer.requestbike())
            customer.rentalBasis = 3
            
        elif choice == 5:
            customer.bill = shop.returnbike(customer.returnbike())
            print(customer.returnbike())
            customer.rentalBasis,customer.rentalTime,customer.bikes = 0,0,0
        elif choice == 6:
            break
            
        else:
            print("invalid input")
            

if __name__ == "__main__":
    main()
# Out:
#         ====== Bike Rental Shop =======
#         1. Display available bikes
#         2. Request a bike on hourly basis $5
#         3. Request a bike on daily basis $20
#         4. Request a bike on weekly basis $60
#         5. Return a bike
#         6. Exit
#
# enter ur choice:1
# we have currently 100 bikes to rent
#
#         ====== Bike Rental Shop =======
#         1. Display available bikes
#         2. Request a bike on hourly basis $5
#         3. Request a bike on daily basis $20
#         4. Request a bike on weekly basis $60
#         5. Return a bike
#         6. Exit
#
# enter ur choice:2
# how many bikes you want for rent?4
# you are rented a 4 bikes today on hourly basis at 23
# you will be charged $5 for each hour per bike
# hope you enjoy our services
#
#         ====== Bike Rental Shop =======
#         1. Display available bikes
#         2. Request a bike on hourly basis $5
#         3. Request a bike on daily basis $20
#         4. Request a bike on weekly basis $60
#         5. Return a bike
#         6. Exit
#
# enter ur choice:5
# youre eligible for discount of 30%
# total bill is 0.0
# (datetime.datetime(2019, 12, 26, 23, 33, 46, 675726), 1, 4)
#
#         ====== Bike Rental Shop =======
#         1. Display available bikes
#         2. Request a bike on hourly basis $5
#         3. Request a bike on daily basis $20
#         4. Request a bike on weekly basis $60
#         5. Return a bike
#         6. Exit
#
# enter ur choice:1
# we have currently 100 bikes to rent
#
#         ====== Bike Rental Shop =======
#         1. Display available bikes
#         2. Request a bike on hourly basis $5
#         3. Request a bike on daily basis $20
#         4. Request a bike on weekly basis $60
#         5. Return a bike
#         6. Exit
#
# enter ur choice:2
# how many bikes you want for rent?6
# you are rented a 6 bikes today on hourly basis at 0
# you will be charged $5 for each hour per bike
# hope you enjoy our services
#
#         ====== Bike Rental Shop =======
#         1. Display available bikes
#         2. Request a bike on hourly basis $5
#         3. Request a bike on daily basis $20
#         4. Request a bike on weekly basis $60
#         5. Return a bike
#         6. Exit
#
# enter ur choice:5
# total bill is 330
# (datetime.datetime(2019, 12, 27, 0, 3, 37, 886489), 1, 6)
#
#         ====== Bike Rental Shop =======
#         1. Display available bikes
#         2. Request a bike on hourly basis $5
#         3. Request a bike on daily basis $20
#         4. Request a bike on weekly basis $60
#         5. Return a bike
#         6. Exit

# %%
# Out:
# 2019-12-26 23:28:14.519869
